# %% [markdown]
# <a href="https://colab.research.google.com/github/DEYVI1/Colabs/blob/main/27_7_23_Excel_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install openpyxl # Para que sea compatible con excel
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
# read csv
# df_excel= pd.
#df_excel = pd.read_hdf('/content/datos.hdf5',key="Salon")
#df_excel =pd.read_parquet('datos.parquet')
df_excel = pd.read_excel("datos.xls")

# %%
df_excel['gender']
# Out:
# 0        female
# 1          male
# 2          male
# 3          male
# 4          male
#           ...
# 99995      male
# 99996    female
# 99997    female
# 99998    female
# 99999      male
# Name: gender, Length: 100000, dtype: object

# %% [markdown]
# # Crea un columa

# %%
# Crea un columa auto increntable
df_excel.reset_index(level=0, inplace=True)

# %%
df_excel
# Out:
#      index  Unnamed: 0  gender race/ethnicity parental level of education  \
# 0        0           0    male        group B            some high school
# 1        1           1    male        group D           bachelor's degree
# 2        2           2    male        group B                some college
# 3        3           3    male        group D                some college
# 4        4           4    male        group D          associate's degree
# ..     ...         ...     ...            ...                         ...
# 995    995         995  female        group A                some college
# 996    996         996  female        group A           bachelor's degree
# 997    997         997  female        group A          associate's degree
# 998    998         998    male        group A             master's degree
# 999    999         999  female        group C             master's degree
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          93             82
# 1    free/reduced                    none          16             92
# 2        standard                    none          72             46
# 3        standard               completed          61             85
# 4        standard               completed          34             95
# ..            ...                     ...         ...            ...
# 995  free/reduced                    none          61             41
# 996      standard                    none          21             82
# 997      standard                    none          63             58
# 998  free/reduced                    none          17             98
# 999  free/reduced                    none          74              8
#
#      writing score
# 0                6
# 1                6
# 2               80
# 3               87
# 4               65
# ..             ...
# 995             99
# 996             32
# 997             44
# 998              8
# 999             10
#
# [1000 rows x 10 columns]

# %% [markdown]
# # Sum, Average, Max, Min, Count

# %% [markdown]
# ## Columns

# %%
# first look
df_excel.describe()
# Out:
#              index   Unnamed: 0   math score  reading score  writing score  \
# count  1000.000000  1000.000000  1000.000000     1000.00000    1000.000000
# mean    499.500000   499.500000    50.033000       50.22800      48.468000
# std     288.819436   288.819436    28.982407       29.19624      28.853761
# min       0.000000     0.000000     0.000000        0.00000       0.000000
# 25%     249.750000   249.750000    26.000000       25.00000      23.000000
# 50%     499.500000   499.500000    49.000000       50.00000      48.000000
# 75%     749.250000   749.250000    74.000000       76.00000      73.000000
# max     999.000000   999.000000   100.000000      100.00000     100.000000
#
#            average
# count  1000.000000
# mean     49.576333
# std      16.269610
# min       4.000000
# 25%      38.666667
# 50%      49.333333
# 75%      60.333333
# max      97.000000

# %%
# calculate specific columns

df_excel['math score'].sum()
# df_excel['math score'].mean()
# df_excel['math score'].max()
# df_excel['math score'].min()
# df_excel['math score'].count()
# Out:
# 50033

# %% [markdown]
# # Rows

# %%
df_excel['average'] = (df_excel['math score'] + df_excel['reading score'] + df_excel['writing score'])/3
# df_excel.mean(axis=1)
df_excel.head(10)
# Out:
#    index  Unnamed: 0  gender race/ethnicity parental level of education  \
# 0      0           0    male        group B            some high school
# 1      1           1    male        group D           bachelor's degree
# 2      2           2    male        group B                some college
# 3      3           3    male        group D                some college
# 4      4           4    male        group D          associate's degree
# 5      5           5  female        group A                some college
# 6      6           6  female        group A           bachelor's degree
# 7      7           7    male        group A            some high school
# 8      8           8  female        group C                some college
# 9      9           9    male        group B                 high school
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none          93             82
# 1  free/reduced                    none          16             92
# 2      standard                    none          72             46
# 3      standard               completed          61             85
# 4      standard               completed          34             95
# 5      standard               completed          95             41
# 6  free/reduced               completed          74             64
# 7      standard               completed          74             38
# 8  free/reduced               completed          67             52
# 9      standard               completed          99             23
#
#    writing score    average pass/fail grades
# 0              6  60.333333      Fail      D
# 1              6  38.000000      Fail      F
# 2             80  66.000000      Fail      D
# 3             87  77.666667      Pass      C
# 4             65  64.666667      Fail      D
# 5              9  48.333333      Fail      F
# 6             81  73.000000      Pass      C
# 7             77  63.000000      Fail      D
# 8             81  66.666667      Fail      D
# 9             58  60.000000      Fail      D

# %%
# count
df_excel['gender'].value_counts()
# Out:
# male      520
# female    480
# Name: gender, dtype: int64

# %% [markdown]
# # IF

# %%
# if condition
df_excel['pass/fail'] = np.where(df_excel['average'] > 70, 'Pass', 'Fail')
df_excel.head()
# Out:
#    index  Unnamed: 0 gender race/ethnicity parental level of education  \
# 0      0           0   male        group B            some high school
# 1      1           1   male        group D           bachelor's degree
# 2      2           2   male        group B                some college
# 3      3           3   male        group D                some college
# 4      4           4   male        group D          associate's degree
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none          93             82
# 1  free/reduced                    none          16             92
# 2      standard                    none          72             46
# 3      standard               completed          61             85
# 4      standard               completed          34             95
#
#    writing score    average pass/fail grades
# 0              6  60.333333      Fail      D
# 1              6  38.000000      Fail      F
# 2             80  66.000000      Fail      D
# 3             87  77.666667      Pass      C
# 4             65  64.666667      Fail      D

# %%
# multiple conditions
conditions = [
    (df_excel['average']>=90),
    (df_excel['average']>=80) & (df_excel['average']<90),
    (df_excel['average']>=70) & (df_excel['average']<80),
    (df_excel['average']>=60) & (df_excel['average']<70),
    (df_excel['average']>=50) & (df_excel['average']<60),
    (df_excel['average']<50),
]

values = ['A', 'B', 'C', 'D', 'E', 'F']

# %%
df_excel['grades'] = np.select(conditions, values)
df_excel.head()
# Out:
#    index  Unnamed: 0 gender race/ethnicity parental level of education  \
# 0      0           0   male        group B            some high school
# 1      1           1   male        group D           bachelor's degree
# 2      2           2   male        group B                some college
# 3      3           3   male        group D                some college
# 4      4           4   male        group D          associate's degree
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none          93             82
# 1  free/reduced                    none          16             92
# 2      standard                    none          72             46
# 3      standard               completed          61             85
# 4      standard               completed          34             95
#
#    writing score    average pass/fail grades
# 0              6  60.333333      Fail      D
# 1              6  38.000000      Fail      F
# 2             80  66.000000      Fail      D
# 3             87  77.666667      Pass      C
# 4             65  64.666667      Fail      D

# %%
# show first 5 rows
df_excel[['average', 'pass/fail', 'grades']].head()
# Out:
#      average pass/fail grades
# 0  60.333333      Fail      D
# 1  38.000000      Fail      F
# 2  66.000000      Fail      D
# 3  77.666667      Pass      C
# 4  64.666667      Fail      D

# %% [markdown]
# # SumIf, CountIf, AverageIf

# %% [markdown]
# ## One condition (select a column with brackets [ ] )

# %%
# only sum scores for the female gender
df_female = df_excel[df_excel['gender'] == 'female']
# df_female['sum'] = df_female.sum(axis=1)

# %% [markdown]
# ## Two or more conditions (select columns and use & or |)

# %%
# solo obtener el promedio para el genero femenino y grupo B
df_sumifs = df_excel[(df_excel['gender'] == 'female') & (df_excel['race/ethnicity'] == 'group B')]
df_sumifs = df_sumifs.assign(sumifs = df_sumifs['math score'] + df_sumifs['reading score'] + df_sumifs['writing score'])
df_sumifs
# Out:
#      index  Unnamed: 0  gender race/ethnicity parental level of education  \
# 18      18          18  female        group B             master's degree
# 44      44          44  female        group B             master's degree
# 46      46          46  female        group B            some high school
# 47      47          47  female        group B            some high school
# 58      58          58  female        group B          associate's degree
# ..     ...         ...     ...            ...                         ...
# 964    964         964  female        group B            some high school
# 967    967         967  female        group B          associate's degree
# 968    968         968  female        group B           bachelor's degree
# 977    977         977  female        group B                 high school
# 989    989         989  female        group B                some college
#
#             lunch test preparation course  math score  reading score  \
# 18       standard               completed           1             23
# 44       standard                    none           9             88
# 46   free/reduced                    none          52             10
# 47   free/reduced               completed          20             67
# 58       standard               completed          87             96
# ..            ...                     ...         ...            ...
# 964      standard               completed          20             23
# 967  free/reduced               completed          12             37
# 968  free/reduced               completed          92             98
# 977  free/reduced               completed          14             12
# 989  free/reduced               completed          77             69
#
#      writing score    average pass/fail grades  sumifs
# 18              53  25.666667      Fail      F      77
# 44               4  33.666667      Fail      F     101
# 46             100  54.000000      Fail      E     162
# 47              87  58.000000      Fail      E     174
# 58               6  63.000000      Fail      D     189
# ..             ...        ...       ...    ...     ...
# 964             86  43.000000      Fail      F     129
# 967             68  39.000000      Fail      F     117
# 968             10  66.666667      Fail      D     200
# 977             17  14.333333      Fail      F      43
# 989            100  82.000000      Pass      B     246
#
# [104 rows x 14 columns]

# %% [markdown]
# # Basic Data Cleaning

# %% [markdown]
# ## Change the case of text with .str.lower, .str.upper or .str.title

# %%
# df_excel['gender'].str.title()
# df_excel['gender'].str.upper()
df_excel['gender'].str.title()
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997    Female
# 998      Male
# 999    Female
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# ## Extract text in a column with .str.extract

# %%
df_excel['race/ethnicity'].str.extract(r'([A-Z])')
# Out:
#      0
# 0    B
# 1    D
# 2    B
# 3    D
# 4    D
# ..  ..
# 995  A
# 996  A
# 997  A
# 998  A
# 999  C
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Identify whether a cell is empty with the .isnull method

# %%
# there's no empty rows in the dataframe
df_excel[df_excel['gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0, gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, average, pass/fail, grades]
# Index: []

# %% [markdown]
# ## Find an element with .loc[ ]

# %%
df_excel.loc[100, ]
# Out:
# index                                      100
# Unnamed: 0                                 100
# gender                                    male
# race/ethnicity                         group E
# parental level of education    master's degree
# lunch                                 standard
# test preparation course                   none
# math score                                  52
# reading score                               24
# writing score                               45
# average                              40.333333
# pass/fail                                 Fail
# grades                                       F
# Name: 100, dtype: object

# %%
df_excel.loc[df_excel['index']==10, 'math score']
# Out:
# 10    45
# Name: math score, dtype: int64

# %% [markdown]
# ## Use the .pivot_table method

# %%
df_pivot = df_excel.pivot_table(index='race/ethnicity', values=['math score', 'writing score'], aggfunc='mean')
df_pivot
# Out:
#                 math score  writing score
# race/ethnicity
# group A          52.175926      45.384259
# group B          50.067961      49.184466
# group C          49.482412      49.130653
# group D          50.883333      46.355556
# group E          47.452261      52.321608

# %% [markdown]
# # Replace Excel Graphs with Python's Matplotlib or Seaborn

# %%
import matplotlib.pyplot as plt

df_plot = df_pivot.reset_index()
plt.bar(df_plot['race/ethnicity'], df_plot['math score'])
plt.show()

# %%
plt.pie(df_plot['math score'], labels=df_plot['race/ethnicity'], autopct='%.0f %%')
plt.show()

# %%
df_pivot.to_excel('Pivot.xlsx')
df_excel.to_excel('RawData.xlsx')
